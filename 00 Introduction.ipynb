# %% [markdown]
# # MonarQ
# MonarQ est un ordinateur quantique universel à base de qubits supraconducteurs
#
# Les qubits supraconducteurs sont contrôlés par micro-ondes
# - La durée des impulsions créent différents états
# - Un résonateur séparé contrôle la superposition et l'intrication de qubits avoisinants
#
# <img src="attachment:aa790b64-e54b-4c3e-bbd3-9485317a915c.png" alt="Superconducting QPU" width=75% height=75% title="Superconducting QPU">
#
# ## Processeur de MonarQ
# <img src="attachment:254405cf-9db7-4a85-89b6-fa755b175213.png" alt="MonarQ Connectivity" width=50% height=50% title="MonarQ Connectivity">
#
# ![MonarQ-GateFidelity.png](attachment:0a491379-9dbe-4eec-8903-4e64dc930d34.png)
